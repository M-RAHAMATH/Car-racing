# %% [markdown]
# <a href="https://colab.research.google.com/github/M-RAHAMATH/Car-racing/blob/main/car_racing_RAHAMATH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CAR RACING

# %% [markdown]
# IMPORTING MODULE

# %%
import gymnasium as gym
import numpy as np
import pygame
import time

# %% [markdown]
# INSTALLING DEPENDENCIES

# %%
# !pip install gymnasium
# !pip install Box2D
# !pip install gymnasium[classic-control]

# %% [markdown]
# CREATING ENVIRONMENT

# %%
import gymnasium as gym
import matplotlib.pyplot as plt

# Create CarRacing environment with rgb_array (returns frames)
env = gym.make("CarRacing-v2", render_mode="rgb_array")

num_episodes = 3
for ep in range(num_episodes):
    obs, info = env.reset(seed=ep)
    total_reward = 0
    step = 0

    print(f"\n🎬 Episode {ep+1} started")

    while True:
        # Random action (replace with keyboard/agent later)
        action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(action)

        total_reward += reward
        step += 1

        # Show every 20th frame inline
        if step % 20 == 0:
            plt.imshow(obs)
            plt.axis("off")
            plt.title(f"Episode {ep+1} - Step {step}")
            plt.show()

        if terminated or truncated:
            print(f"🏁 Episode {ep+1} finished at step {step} with reward {total_reward:.2f}")
            break

env.close()
# Out:
# 🎬 Episode 1 started
# 🏁 Episode 1 finished at step 1000 with reward -40.44
#
# 🎬 Episode 2 started
# 🏁 Episode 2 finished at step 1000 with reward -27.27
#
# 🎬 Episode 3 started
# 🏁 Episode 3 finished at step 1000 with reward -40.30
